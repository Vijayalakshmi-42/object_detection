# %% [markdown]
# <a href="https://colab.research.google.com/github/Vijayalakshmi-42/object_detection/blob/main/Untitled16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics opencv-python matplotlib

# %%
import cv2
import matplotlib.pyplot as plt
from ultralytics import YOLO

# %%
#load pre trained yolo model
model = YOLO("yolov8n.pt")

# %%
#upload file to google colad
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2c2cc267-e2c7-4899-ada8-58a85ba97941" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2c2cc267-e2c7-4899-ada8-58a85ba97941">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#read the image with cv2 with large path
image_pth=list(uploaded.keys())[0]
img=cv2.imread(image_pth)
#convert BGR to RGB for display
img_rgb=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

#display the image
plt.imshow(img_rgb)
plt.axis(False)
plt.show()

# %%
#perform object detection
results=model(img)
# Out:
# 0: 448x640 6 persons, 6 cups, 1 dining table, 1 cell phone, 1 book, 163.4ms
# Speed: 5.4ms preprocess, 163.4ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)

# %%
#draw bounding boxes on image
annotated_image=results[0].plot()
#display the annotated image
plt.figure(figsize=(10,10))
plt.imshow(annotated_image)
plt.axis('off')
plt.show()
